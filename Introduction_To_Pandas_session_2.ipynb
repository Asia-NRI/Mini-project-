# %% [markdown]
# <a href="https://colab.research.google.com/github/Asia-NRI/Mini-project-/blob/main/Introduction_To_Pandas_session_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ds=pd.read_csv('/content/drive/MyDrive/Shaik Asia')

# %%
ds
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# ...

# %%
ds.shape
# Out:
# (690, 16)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  690 non-null    int64
#  1   A1          690 non-null    int64
#  2   A2          690 non-null    float64
#  3   A3          690 non-null    float64
#  4   A4          690 non-null    int64
#  5   A5          690 non-null    int64
#  6   A6          690 non-null    int64
#  7   A7          690 non-null    float64
#  8   A8          690 non-null    int64
#  9   A9          690 non-null    int64
#  10  A10         690 non-null    int64
#  11  A11         690 non-null    int64
#  12  A12         690 non-null    int64
#  13  A13         690 non-null    int64
#  14  A14         690 non-null    int64
#  15  Class       690 non-null    int64
# dtypes: float64(3), int64(13)
# memory usage: 86.4 KB

# %%
import random
age=[]
height=[]
weight=[]
speed=[]
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))
  idata={'Age':age,'Height':height,'Weight':weight,'Speed':speed}

# %%
idata
# Out:
# {'Age': [74,
#   59,
#   73,
#   23,
#   89,
#   24,
#   60,
#   96,
#   69,
#   88,
#   54,
#   91,
#   56,
#   51,
#   48,
#   55,
#   77,
#   70,
#   30,
#   35,
#   11,
#   21,
#   83,
#   5,
#   35,
#   53,
#   38,
#   85,
#   65,
#   72,
#   29,
#   7,
#   76,
#   52,
#   32,
#   76,
#   12,
#   100,
#   96,
#   85,
#   90,
#   57,
#   23,
#   0,
#   58,
#   92,
#   53,
#   42,
#   93,
#   99,
#   48,
#   11,
#   33,
#   91,
#   9,
#   22,
#   24,
#   90,
#   3,
#   77,
#   59,
#   18,
#   24,
#   73,
#   74,
#   84,
#   58,
#   55,
#   70,
#   41,
#   62,
#   3,
#   92,
#   95,
#   64,
#   32,
#   15,
#   60,
#   87,
#   57,
#   46,
#   36,
#   76,
#   50,
#   9,
#   18,
#   27,
#   99,
#   40,
#   7,
#   8,
#   33,
#   42,
#   52,
#   53,
#   0,
#   35,
#   63,
#   77,
#   57],
#  'Height': [60,
#   15,
#   74,
#   81,
#   43,
#   47,
#   48,
#   54,
#   3,
#   31,
#   27,
#   66,
#   13,
#   93,
#   19,
#   15,
#   3,
#   52,
#   76,
#   89,
#   16,
#   71,
#   62,
#   98,
# ...

# %%
df1 = pd.DataFrame(idata)

# %%
df1
# Out:
#     Age  Height  Weight  Speed
# 0    93       9      65      5
# 1    49      11      56     90
# 2    79      31      85     52
# 3     2      78      85     58
# 4    37       6      79     72
# ..  ...     ...     ...    ...
# 95   95       2      42     41
# 96   77      83      55     68
# 97   30      46      11     73
# 98   79      63       3     90
# 99    7       5      63     27
#
# [100 rows x 4 columns]

# %%
df1['Age']
# Out:
# 0     43
# 1     62
# 2     77
# 3     53
# 4     56
#       ..
# 95    51
# 96    59
# 97    68
# 98    87
# 99     1
# Name: Age, Length: 100, dtype: int64

# %%
df1.loc[[0,3],['Age','Height']]
# Out:
#    Age  Height
# 0   43      48
# 3   53      62

# %%
df2=df1[['Age','Height']]

# %%
df2[0::2]
# Out:
#     Age  Height
# 0    93       9
# 2    79      31
# 4    37       6
# 6   100      38
# 8    21      26
# 10   69      42
# 12   35      41
# 14   17      10
# 16   77      63
# 18    0      72
# 20   66      35
# 22   63      34
# 24   86      84
# 26   91      79
# 28   40      61
# 30   74      59
# 32   40       9
# 34   33      88
# 36   53      45
# 38   78      34
# 40   21     100
# 42   24      22
# 44   13      69
# 46   36      76
# 48   25      83
# 50   74      72
# 52   80      18
# 54   54      93
# 56   12      88
# 58   64      62
# 60   35      74
# 62   19      36
# 64   91      70
# 66   67      20
# 68   42      94
# 70   78      60
# 72   56      88
# 74   95      59
# 76   44      62
# 78   24      80
# 80   19      28
# 82   60      50
# 84   38      69
# 86   58      60
# 88   63      93
# 90   58      30
# 92   34      68
# 94   11      87
# 96   77      83
# 98   79      63

# %%
df1[0::2].describe()
# Out:
#               Age      Height     Weight      Speed
# count   50.000000   50.000000  50.000000  50.000000
# mean    52.060000   56.460000  48.840000  48.060000
# std     26.579423   26.446874  25.872024  28.266523
# min      0.000000    6.000000   3.000000   0.000000
# 25%     33.250000   34.250000  30.000000  25.250000
# 50%     55.000000   61.500000  44.500000  49.000000
# 75%     76.250000   78.250000  71.250000  76.500000
# max    100.000000  100.000000  92.000000  94.000000

# %%
#filter

# %%
df1['Weight']>50
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
#       ...
# 95    False
# 96     True
# 97    False
# 98    False
# 99    False
# Name: Weight, Length: 100, dtype: bool

# %%
df1
# Out:
#     Age  Height  Weight  Speed
# 0    74      60      33     13
# 1    59      15      10     99
# 2    73      74      14     16
# 3    23      81      28     93
# 4    89      43      72     31
# ..  ...     ...     ...    ...
# 95    0       1      23      0
# 96   35       5      97      8
# 97   63      80       1     77
# 98   77      86      41      6
# 99   57      36      40     47
#
# [100 rows x 4 columns]
